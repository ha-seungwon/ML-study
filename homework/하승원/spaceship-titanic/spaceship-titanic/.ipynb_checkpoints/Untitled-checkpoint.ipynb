# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
sub=pd.read_csv('sample_submission.csv')

# %%
def id_seperate(df):
    group=[]
    group_num=[]
    for i in df.index:
        id_=df.loc[i]['PassengerId']
        temp=id_.split('_')
        group.append(temp[0])
        group_num.append(temp[1])
        
    df['group']=group
    df['group_num']=group_num
    return df

def cabin_seperate(df):
    deck=[]
    num=[]
    side=[]
    for i in df.index:
        id_=df.loc[i]['Cabin']
        if type(id_)==float :
            deck.append('0')
            num.append('0')
            side.append('0')
        else:
            temp=id_.split('/')
            deck.append(temp[0])
            num.append(temp[1])
            side.append(temp[2])
        
    df['Cabin_deck']=deck
    df['Cabin_num']=num
    df['Cabin_side']=side
    return df


def name_seperate(df):
    first=[]
    last=[]

    for i in df.index:
        id_=df.loc[i]['Name']
        if type(id_)==float :
            first.append('0')
            last.append('0')
        else:
            temp=id_.split(' ')
            first.append(temp[0])
            last.append(temp[1])
        
    df['Name_first']=first
    df['Name_last']=last
    return df

def labeling_code(df,col):
    encoder=LabelEncoder()
    encoder.fit(df[col])
    enco=encoder.transform(df[col])
    df[col]=enco
    return df

# %%
train.isna().sum()
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Cabin           199
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# Name            200
# Transported       0
# dtype: int64

# %% [markdown]
# # preprocessing

# %%
train=id_seperate(train)
test=id_seperate(test)

train=cabin_seperate(train)
test=cabin_seperate(test)


#train=name_seperate(train)
#test=name_seperate(test)

# %%
train=train.drop('PassengerId',axis=1)
test=test.drop('PassengerId',axis=1)

train=train.drop('Cabin',axis=1)
test=test.drop('Cabin',axis=1)

train=train.drop('Name',axis=1)
test=test.drop('Name',axis=1)

# %%
train=labeling_code(train,'HomePlanet')
train=labeling_code(train,'Destination')
test=labeling_code(test,'HomePlanet')
test=labeling_code(test,'Destination')

# %%
train=labeling_code(train,'Cabin_deck')
test=labeling_code(test,'Cabin_deck')
train=labeling_code(train,'Cabin_side')
test=labeling_code(test,'Cabin_side')

# %% [markdown]
# # 결측치 처리

# %%
train=labeling_code(train,'CryoSleep')
test=labeling_code(test,'CryoSleep')
train['CryoSleep']=train['CryoSleep'].astype(float)
test['CryoSleep']=test['CryoSleep'].astype(float)

# %%
train['VIP']=train['VIP'].astype(float)
test['VIP']=test['VIP'].astype(float)

# %%
train['Age']=train['Age'].fillna(train['Age'].mean())
test['Age']=test['Age'].fillna(test['Age'].mean())
train[['RoomService','FoodCourt','ShoppingMall','Spa','VRDeck','VIP','CryoSleep']]=train[['RoomService','FoodCourt','ShoppingMall','Spa','VRDeck','VIP','CryoSleep']].fillna(0)
test[['RoomService','FoodCourt','ShoppingMall','Spa','VRDeck','VIP','CryoSleep']]=test[['RoomService','FoodCourt','ShoppingMall','Spa','VRDeck','VIP','CryoSleep']].fillna(0)

# %%
train['group']=train['group'].astype(int)
test['group']=test['group'].astype(int)
train['group_num']=train['group_num'].astype(int)
test['group_num']=test['group_num'].astype(int)
train['Cabin_num']=train['Cabin_num'].astype(int)
test['Cabin_num']=test['Cabin_num'].astype(int)

# %%
pd.get_dummies(train,columns=['Cabin_side'])
pd.get_dummies(test,columns=['Cabin_side'])
# Out:
#       HomePlanet  CryoSleep  Destination        Age  VIP  RoomService  \
# 0              0        1.0            2  27.000000  0.0          0.0
# 1              0        0.0            2  19.000000  0.0          0.0
# 2              1        1.0            0  31.000000  0.0          0.0
# 3              1        0.0            2  38.000000  0.0          0.0
# 4              0        0.0            2  20.000000  0.0         10.0
# ...          ...        ...          ...        ...  ...          ...
# 4272           0        1.0            2  34.000000  0.0          0.0
# 4273           0        0.0            2  42.000000  0.0          0.0
# 4274           2        1.0            0  28.658146  0.0          0.0
# 4275           1        0.0            3  28.658146  0.0          0.0
# 4276           0        1.0            1  43.000000  0.0          0.0
#
#       FoodCourt  ShoppingMall     Spa  VRDeck  group  group_num  Cabin_deck  \
# 0           0.0           0.0     0.0     0.0     13          1           7
# 1           9.0           0.0  2823.0     0.0     18          1           6
# 2           0.0           0.0     0.0     0.0     19          1           3
# 3        6652.0           0.0   181.0   585.0     21          1           3
# 4           0.0         635.0     0.0     0.0     23          1           6
# ...         ...           ...     ...     ...    ...        ...         ...
# 4272        0.0           0.0     0.0     0.0   9266          2           7
# 4273      847.0          17.0    10.0   144.0   9269          1           0
# 4274        0.0           0.0     0.0     0.0   9271          1           4
# 4275     2680.0           0.0     0.0   523.0   9273          1           4
# 4276        0.0           0.0     0.0     0.0   9277          1           7
#
#       Cabin_num  Cabin_side_0  Cabin_side_1  Cabin_side_2
# 0             3             0             0             1
# 1             4             0             0             1
# 2             0             0             0             1
# 3             1             0             0             1
# 4             5             0             0             1
# ...         ...           ...           ...           ...
# 4272       1496             0             0             1
# 4273          0             1             0             0
# 4274        296             0             1             0
# 4275        297             0             1             0
# 4276       1498             0             0             1
#
# [4277 rows x 17 columns]

# %%
train['Transported']=train['Transported'].astype(int)

# %%
y=train['Transported']
x=train.drop('Transported',axis=1)

# %%
from xgboost import XGBClassifier
{'colsample_bytree': 0.5, 'eta': 0.025, 'gamma': 0.75, 'max_depth': 3, 'min_child_weight': 6.0, 
 'n_estimators': 465.0, 'subsample': 0.8500000000000001}
# Out:
# {'colsample_bytree': 0.5,
#  'eta': 0.025,
#  'gamma': 0.75,
#  'max_depth': 3,
#  'min_child_weight': 6.0,
#  'n_estimators': 465.0,
#  'subsample': 0.8500000000000001}

# %%
model = XGBClassifier(colsample_bytree= 0.75, eta= 0.025, gamma= 0.5, max_depth= 4, min_child_weight=1.0, 
                      n_estimators= 650, subsample=1.0)
model.fit(x,y)
pred = model.predict(test)

# %%
sub['Transported']=pred.astype(bool)

sub.to_csv('result.csv', index=False)

# %%
sub['Transported'].value_counts()
# 0.80313
#True     2210
#False    2067


#Score: 0.80804
#True     2221
#False    2056


#Score: 0.80430
#이름추가
#True     2207
#False    2070
# Out:
# True     2221
# False    2056
# Name: Transported, dtype: int64

# %%
# Data wrangling

import pandas as pd

# Scientific 

import numpy as np


# Machine learning

import xgboost as xgb
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import roc_auc_score

# Hyperparameters tuning

from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# Some constants

SEED = 314159265
VALID_SIZE = 0.3
TARGET = 'outcome'

def optimize(
             #trials, 
             random_state=SEED):
    """
    This is the optimization function that given a space (space here) of 
    hyperparameters and a scoring function (score here), finds the best hyperparameters.
    """
    # To learn more about XGBoost parameters, head to this page: 
    # https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
    space = {
        'n_estimators': hp.quniform('n_estimators', 100, 1000, 5),
        'eta': hp.quniform('eta', 0.025, 0.5, 0.025),
        # A problem with max_depth casted to float instead of int with
        # the hp.quniform method.
        'max_depth':  hp.choice('max_depth', np.arange(1, 14, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
        'subsample': hp.quniform('subsample', 0.5, 1, 0.05),
        'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
        'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.05),
        'eval_metric': 'auc',
        'objective': 'binary:logistic',
        # Increase this number if you have more cores. Otherwise, remove it and it will default 
        # to the maxium number. 
        'nthread': 4,
        'booster': 'gbtree',
        'tree_method': 'exact',
        'silent': 1,
        'seed': random_state
    }
    # Use the fmin function from Hyperopt to find the best hyperparameters
    best = fmin(score, space, algo=tpe.suggest, 
                # trials=trials, 
                max_evals=50)
    return best

def score(params):
    print("Training with params: ")
    print(params)
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(train_features, label=y_train)
    dvalid = xgb.DMatrix(valid_features, label=y_valid)
    watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    gbm_model = xgb.train(params, dtrain, num_round,
                          evals=watchlist,
                          verbose_eval=True)
    predictions = gbm_model.predict(dvalid,
                                    ntree_limit=gbm_model.best_iteration + 1)
    score = roc_auc_score(y_valid, predictions)
    # TODO: Add the importance for the selected features
    print("\tScore {0}\n\n".format(score))
    # The score function should return the loss (1-score)
    # since the optimize function looks for the minimum
    loss = 1 - score
    return {'loss': loss, 'status': STATUS_OK}

# %%
from sklearn.model_selection import train_test_split
train_df=train.copy()

train, valid = train_test_split(train_df, test_size=VALID_SIZE,
                                random_state=SEED)


y_train = train['Transported']
y_valid = valid['Transported']
train_features = train.drop('Transported',axis=1)
valid_features = valid.drop('Transported',axis=1)

# %%
best_hyperparams = optimize(
                            #trials
                            )
print("The best hyperparameters are: ", "\n")
print(best_hyperparams)
# Out:
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 6, 'min_child_weight': 2.0, 'n_estimators': 255.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'silent': 1, 'subsample': 0.9, 'tree_method': 'exact'}
# [15:35:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	eval-auc:0.83604	train-auc:0.85932
# [1]	eval-auc:0.86212	train-auc:0.88782
# [2]	eval-auc:0.87183	train-auc:0.89960
# [3]	eval-auc:0.87404	train-auc:0.90707
# [4]	eval-auc:0.87565	train-auc:0.91113
# [5]	eval-auc:0.87673	train-auc:0.91547
# [6]	eval-auc:0.87884	train-auc:0.92180
# [7]	eval-auc:0.88094	train-auc:0.92514
# [8]	eval-auc:0.88253	train-auc:0.92916
# [9]	eval-auc:0.88384	train-auc:0.93223
# [10]	eval-auc:0.88419	train-auc:0.93502
# [11]	eval-auc:0.88435	train-auc:0.93665
# [12]	eval-auc:0.88423	train-auc:0.93778
# [13]	eval-auc:0.88492	train-auc:0.93902
# [14]	eval-auc:0.88540	train-auc:0.93945
# [15]	eval-auc:0.88583	train-auc:0.94118
# [16]	eval-auc:0.88709	train-auc:0.94275
# [17]	eval-auc:0.88754	train-auc:0.94404
# [18]	eval-auc:0.88711	train-auc:0.94605
# [19]	eval-auc:0.88794	train-auc:0.94693
# [20]	eval-auc:0.88800	train-auc:0.94785
# [21]	eval-auc:0.88805	train-auc:0.94841
# [22]	eval-auc:0.88612	train-auc:0.95122
# [23]	eval-auc:0.88627	train-auc:0.95153
# [24]	eval-auc:0.88645	train-auc:0.95201
# [25]	eval-auc:0.88621	train-auc:0.95391
# [26]	eval-auc:0.88598	train-auc:0.95476
# [27]	eval-auc:0.88570	train-auc:0.95524
# [28]	eval-auc:0.88532	train-auc:0.95592
# [29]	eval-auc:0.88537	train-auc:0.95644
# [30]	eval-auc:0.88464	train-auc:0.95800
# [31]	eval-auc:0.88496	train-auc:0.95966
# [32]	eval-auc:0.88464	train-auc:0.96036
# [33]	eval-auc:0.88440	train-auc:0.96082
# [34]	eval-auc:0.88413	train-auc:0.96109
# [35]	eval-auc:0.88393	train-auc:0.96214
# [36]	eval-auc:0.88319	train-auc:0.96396
# [37]	eval-auc:0.88294	train-auc:0.96486
# [38]	eval-auc:0.88309	train-auc:0.96534
# [39]	eval-auc:0.88327	train-auc:0.96568
# [40]	eval-auc:0.88299	train-auc:0.96683
# [41]	eval-auc:0.88267	train-auc:0.96731
# [42]	eval-auc:0.88297	train-auc:0.96782
# [43]	eval-auc:0.88264	train-auc:0.96923
# [44]	eval-auc:0.88246	train-auc:0.96983
# [45]	eval-auc:0.88269	train-auc:0.97052
# [46]	eval-auc:0.88261	train-auc:0.97173
# [47]	eval-auc:0.88285	train-auc:0.97268
# [48]	eval-auc:0.88328	train-auc:0.97302
# [49]	eval-auc:0.88294	train-auc:0.97375
# [50]	eval-auc:0.88281	train-auc:0.97463
# [51]	eval-auc:0.88237	train-auc:0.97563
# [52]	eval-auc:0.88224	train-auc:0.97620
# [53]	eval-auc:0.88230	train-auc:0.97631
# [54]	eval-auc:0.88243	train-auc:0.97639
# [55]	eval-auc:0.88191	train-auc:0.97680
# [56]	eval-auc:0.88141	train-auc:0.97756
# [57]	eval-auc:0.88242	train-auc:0.97852
# [58]	eval-auc:0.88226	train-auc:0.97879
# [59]	eval-auc:0.88164	train-auc:0.97931
# [60]	eval-auc:0.88134	train-auc:0.98007
# [61]	eval-auc:0.88198	train-auc:0.98040
# [62]	eval-auc:0.88208	train-auc:0.98041
# [63]	eval-auc:0.88208	train-auc:0.98063
# [64]	eval-auc:0.88168	train-auc:0.98137
# [65]	eval-auc:0.88164	train-auc:0.98177
# [66]	eval-auc:0.88120	train-auc:0.98216
# [67]	eval-auc:0.88103	train-auc:0.98237
# [68]	eval-auc:0.88092	train-auc:0.98254
# [69]	eval-auc:0.88021	train-auc:0.98321
# [70]	eval-auc:0.88049	train-auc:0.98372
# [71]	eval-auc:0.88012	train-auc:0.98466
# [72]	eval-auc:0.87978	train-auc:0.98528
# [73]	eval-auc:0.87987	train-auc:0.98544
# [74]	eval-auc:0.87971	train-auc:0.98569
# [75]	eval-auc:0.88007	train-auc:0.98587
# [76]	eval-auc:0.87994	train-auc:0.98601
# [77]	eval-auc:0.87972	train-auc:0.98679
# [78]	eval-auc:0.87954	train-auc:0.98710
# [79]	eval-auc:0.87926	train-auc:0.98744
# [80]	eval-auc:0.87923	train-auc:0.98751
# [81]	eval-auc:0.87923	train-auc:0.98760
# [82]	eval-auc:0.87923	train-auc:0.98781
# [83]	eval-auc:0.87958	train-auc:0.98808
# [84]	eval-auc:0.87944	train-auc:0.98868
# [85]	eval-auc:0.87934	train-auc:0.98894
# [86]	eval-auc:0.87923	train-auc:0.98928
# [87]	eval-auc:0.87854	train-auc:0.98971
# [88]	eval-auc:0.87843	train-auc:0.98975
# [89]	eval-auc:0.87849	train-auc:0.98997
# [90]	eval-auc:0.87846	train-auc:0.99017
# [91]	eval-auc:0.87836	train-auc:0.99044
# [92]	eval-auc:0.87800	train-auc:0.99064
# [93]	eval-auc:0.87815	train-auc:0.99082
# [94]	eval-auc:0.87825	train-auc:0.99083
# [95]	eval-auc:0.87816	train-auc:0.99104
# [96]	eval-auc:0.87757	train-auc:0.99127
# [97]	eval-auc:0.87776	train-auc:0.99143
# [98]	eval-auc:0.87725	train-auc:0.99160
# [99]	eval-auc:0.87743	train-auc:0.99183
# [100]	eval-auc:0.87739	train-auc:0.99207
# [101]	eval-auc:0.87714	train-auc:0.99232
# [102]	eval-auc:0.87683	train-auc:0.99250
# [103]	eval-auc:0.87632	train-auc:0.99271
# [104]	eval-auc:0.87658	train-auc:0.99275
# [105]	eval-auc:0.87672	train-auc:0.99293
# [106]	eval-auc:0.87636	train-auc:0.99302
# [107]	eval-auc:0.87628	train-auc:0.99312
# [108]	eval-auc:0.87655	train-auc:0.99320
# [109]	eval-auc:0.87668	train-auc:0.99328
# [110]	eval-auc:0.87688	train-auc:0.99326
# [111]	eval-auc:0.87672	train-auc:0.99341
# [112]	eval-auc:0.87695	train-auc:0.99348
# [113]	eval-auc:0.87664	train-auc:0.99354
# [114]	eval-auc:0.87666	train-auc:0.99361
# [115]	eval-auc:0.87651	train-auc:0.99375
# [116]	eval-auc:0.87647	train-auc:0.99378
# [117]	eval-auc:0.87643	train-auc:0.99389
# [118]	eval-auc:0.87658	train-auc:0.99390
# [119]	eval-auc:0.87599	train-auc:0.99396
# [120]	eval-auc:0.87591	train-auc:0.99406
# [121]	eval-auc:0.87597	train-auc:0.99413
# [122]	eval-auc:0.87582	train-auc:0.99422
# [123]	eval-auc:0.87554	train-auc:0.99434
# [124]	eval-auc:0.87553	train-auc:0.99444
# [125]	eval-auc:0.87559	train-auc:0.99456
# [126]	eval-auc:0.87573	train-auc:0.99461
# [127]	eval-auc:0.87537	train-auc:0.99488
# [128]	eval-auc:0.87525	train-auc:0.99497
# [129]	eval-auc:0.87492	train-auc:0.99507
# [130]	eval-auc:0.87482	train-auc:0.99512
# [131]	eval-auc:0.87502	train-auc:0.99521
# [132]	eval-auc:0.87513	train-auc:0.99531
# [133]	eval-auc:0.87504	train-auc:0.99536
# [134]	eval-auc:0.87493	train-auc:0.99552
# [135]	eval-auc:0.87462	train-auc:0.99578
# [136]	eval-auc:0.87437	train-auc:0.99582
# [137]	eval-auc:0.87422	train-auc:0.99588
# [138]	eval-auc:0.87381	train-auc:0.99598
# [139]	eval-auc:0.87403	train-auc:0.99604
# [140]	eval-auc:0.87419	train-auc:0.99605
# [141]	eval-auc:0.87453	train-auc:0.99606
# [142]	eval-auc:0.87458	train-auc:0.99613
# [143]	eval-auc:0.87439	train-auc:0.99614
# [144]	eval-auc:0.87432	train-auc:0.99617
# [145]	eval-auc:0.87440	train-auc:0.99626
# [146]	eval-auc:0.87466	train-auc:0.99635
# [147]	eval-auc:0.87466	train-auc:0.99636
# [148]	eval-auc:0.87453	train-auc:0.99641
# [149]	eval-auc:0.87440	train-auc:0.99644
# [150]	eval-auc:0.87449	train-auc:0.99656
# [151]	eval-auc:0.87470	train-auc:0.99661
# [152]	eval-auc:0.87464	train-auc:0.99665
# [153]	eval-auc:0.87433	train-auc:0.99668
# [154]	eval-auc:0.87420	train-auc:0.99675
# [155]	eval-auc:0.87426	train-auc:0.99676
# [156]	eval-auc:0.87429	train-auc:0.99677
# [157]	eval-auc:0.87392	train-auc:0.99683
# [158]	eval-auc:0.87396	train-auc:0.99687
# [159]	eval-auc:0.87379	train-auc:0.99695
# [160]	eval-auc:0.87400	train-auc:0.99705
# [161]	eval-auc:0.87367	train-auc:0.99715
# [162]	eval-auc:0.87385	train-auc:0.99717
# [163]	eval-auc:0.87392	train-auc:0.99716
# [164]	eval-auc:0.87396	train-auc:0.99724
# [165]	eval-auc:0.87385	train-auc:0.99738
# [166]	eval-auc:0.87371	train-auc:0.99742
# [167]	eval-auc:0.87371	train-auc:0.99742
# [168]	eval-auc:0.87386	train-auc:0.99742
# [169]	eval-auc:0.87391	train-auc:0.99749
# [170]	eval-auc:0.87399	train-auc:0.99760
# [171]	eval-auc:0.87393	train-auc:0.99765
# [172]	eval-auc:0.87389	train-auc:0.99768
# [173]	eval-auc:0.87423	train-auc:0.99772
# [174]	eval-auc:0.87414	train-auc:0.99774
# [175]	eval-auc:0.87430	train-auc:0.99779
# [176]	eval-auc:0.87418	train-auc:0.99779
# [177]	eval-auc:0.87434	train-auc:0.99778
# [178]	eval-auc:0.87439	train-auc:0.99786
# [179]	eval-auc:0.87466	train-auc:0.99793
# [180]	eval-auc:0.87481	train-auc:0.99795
# [181]	eval-auc:0.87490	train-auc:0.99795
# [182]	eval-auc:0.87473	train-auc:0.99803
# [183]	eval-auc:0.87474	train-auc:0.99810
# [184]	eval-auc:0.87461	train-auc:0.99824
# [185]	eval-auc:0.87427	train-auc:0.99828
# [186]	eval-auc:0.87431	train-auc:0.99833
# [187]	eval-auc:0.87426	train-auc:0.99838
# [188]	eval-auc:0.87394	train-auc:0.99845
# [189]	eval-auc:0.87422	train-auc:0.99844
# [190]	eval-auc:0.87427	train-auc:0.99848
# [191]	eval-auc:0.87422	train-auc:0.99850
# [192]	eval-auc:0.87429	train-auc:0.99852
# [193]	eval-auc:0.87417	train-auc:0.99854
# [194]	eval-auc:0.87400	train-auc:0.99859
# [195]	eval-auc:0.87411	train-auc:0.99860
# [196]	eval-auc:0.87420	train-auc:0.99862
# [197]	eval-auc:0.87418	train-auc:0.99864
# [198]	eval-auc:0.87423	train-auc:0.99866
# [199]	eval-auc:0.87390	train-auc:0.99869
# [200]	eval-auc:0.87391	train-auc:0.99871
# [201]	eval-auc:0.87357	train-auc:0.99873
# [202]	eval-auc:0.87346	train-auc:0.99875
# [203]	eval-auc:0.87390	train-auc:0.99876
# [204]	eval-auc:0.87379	train-auc:0.99875
# [205]	eval-auc:0.87382	train-auc:0.99878
# [206]	eval-auc:0.87385	train-auc:0.99881
# [207]	eval-auc:0.87426	train-auc:0.99881
# [208]	eval-auc:0.87429	train-auc:0.99882
# [209]	eval-auc:0.87414	train-auc:0.99885
# [210]	eval-auc:0.87423	train-auc:0.99887
# [211]	eval-auc:0.87399	train-auc:0.99888
# [212]	eval-auc:0.87405	train-auc:0.99889
# [213]	eval-auc:0.87358	train-auc:0.99894
# [214]	eval-auc:0.87358	train-auc:0.99896
# [215]	eval-auc:0.87363	train-auc:0.99901
# [216]	eval-auc:0.87323	train-auc:0.99902
# [217]	eval-auc:0.87320	train-auc:0.99902
# [218]	eval-auc:0.87320	train-auc:0.99903
# [219]	eval-auc:0.87297	train-auc:0.99903
# [220]	eval-auc:0.87319	train-auc:0.99903
# [221]	eval-auc:0.87319	train-auc:0.99903
# [222]	eval-auc:0.87306	train-auc:0.99905
# [223]	eval-auc:0.87306	train-auc:0.99906
# [224]	eval-auc:0.87328	train-auc:0.99907
# [225]	eval-auc:0.87324	train-auc:0.99907
# [226]	eval-auc:0.87325	train-auc:0.99907
# [227]	eval-auc:0.87334	train-auc:0.99907
# [228]	eval-auc:0.87334	train-auc:0.99909
# [229]	eval-auc:0.87321	train-auc:0.99915
# [230]	eval-auc:0.87320	train-auc:0.99916
# [231]	eval-auc:0.87333	train-auc:0.99916
# [232]	eval-auc:0.87342	train-auc:0.99920
# [233]	eval-auc:0.87319	train-auc:0.99924
# [234]	eval-auc:0.87312	train-auc:0.99926
# [235]	eval-auc:0.87284	train-auc:0.99926
# [236]	eval-auc:0.87272	train-auc:0.99932
# [237]	eval-auc:0.87274	train-auc:0.99933
# [238]	eval-auc:0.87268	train-auc:0.99937
# [239]	eval-auc:0.87253	train-auc:0.99941
# [240]	eval-auc:0.87276	train-auc:0.99941
# [241]	eval-auc:0.87261	train-auc:0.99941
# [242]	eval-auc:0.87259	train-auc:0.99942
# [243]	eval-auc:0.87253	train-auc:0.99942
# [244]	eval-auc:0.87253	train-auc:0.99942
# [245]	eval-auc:0.87259	train-auc:0.99943
# [246]	eval-auc:0.87258	train-auc:0.99943
# [247]	eval-auc:0.87245	train-auc:0.99943
# [248]	eval-auc:0.87255	train-auc:0.99943
# [249]	eval-auc:0.87242	train-auc:0.99943
# [250]	eval-auc:0.87259	train-auc:0.99943
# [251]	eval-auc:0.87252	train-auc:0.99942
# [252]	eval-auc:0.87226	train-auc:0.99945
# [253]	eval-auc:0.87243	train-auc:0.99945
# [254]	eval-auc:0.87251	train-auc:0.99944
# 	Score 0.8725144181682717
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 9, 'min_child_weight': 2.0, 'n_estimators': 660.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'silent': 1, 'subsample': 0.8, 'tree_method': 'exact'}
# [15:35:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	eval-auc:0.84085	train-auc:0.89418
# [1]	eval-auc:0.85379	train-auc:0.91910
# [2]	eval-auc:0.87151	train-auc:0.93270
# [3]	eval-auc:0.87587	train-auc:0.93715
# [4]	eval-auc:0.87782	train-auc:0.94416
# [5]	eval-auc:0.87795	train-auc:0.94932
# [6]	eval-auc:0.87739	train-auc:0.95133
# [7]	eval-auc:0.87959	train-auc:0.95598
# [8]	eval-auc:0.88155	train-auc:0.95886
# [9]	eval-auc:0.88159	train-auc:0.96058
# [10]	eval-auc:0.88308	train-auc:0.96263
# [11]	eval-auc:0.88214	train-auc:0.96565
# [12]	eval-auc:0.88147	train-auc:0.96676
# [13]	eval-auc:0.88100	train-auc:0.96945
# [14]	eval-auc:0.88106	train-auc:0.97058
# [15]	eval-auc:0.88105	train-auc:0.97125
# [16]	eval-auc:0.88210	train-auc:0.97255
# [17]	eval-auc:0.88214	train-auc:0.97356
# [18]	eval-auc:0.88302	train-auc:0.97481
#   2%|▏         | 1/50 [00:01<01:26,  1.76s/trial, best loss: 0.1274855818317283]
# /Users/haseung-won/opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:91: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# [19]	eval-auc:0.88320	train-auc:0.97568
# [20]	eval-auc:0.88269	train-auc:0.97705
# [21]	eval-auc:0.88204	train-auc:0.97784
# [22]	eval-auc:0.88150	train-auc:0.97923
# [23]	eval-auc:0.88137	train-auc:0.97977
# [24]	eval-auc:0.88129	train-auc:0.98008
# [25]	eval-auc:0.88110	train-auc:0.98036
# [26]	eval-auc:0.88090	train-auc:0.98071
# [27]	eval-auc:0.88115	train-auc:0.98206
# [28]	eval-auc:0.88095	train-auc:0.98362
# [29]	eval-auc:0.88162	train-auc:0.98437
# [30]	eval-auc:0.88065	train-auc:0.98561
# [31]	eval-auc:0.88026	train-auc:0.98728
# [32]	eval-auc:0.88026	train-auc:0.98796
# [33]	eval-auc:0.87943	train-auc:0.98849
# [34]	eval-auc:0.87971	train-auc:0.98877
# [35]	eval-auc:0.87957	train-auc:0.98903
# [36]	eval-auc:0.87986	train-auc:0.98961
# [37]	eval-auc:0.87964	train-auc:0.98988
# [38]	eval-auc:0.87997	train-auc:0.99047
# [39]	eval-auc:0.88028	train-auc:0.99085
# [40]	eval-auc:0.88037	train-auc:0.99086
# [41]	eval-auc:0.88032	train-auc:0.99116
# [42]	eval-auc:0.87976	train-auc:0.99148
# [43]	eval-auc:0.87960	train-auc:0.99190
# [44]	eval-auc:0.87963	train-auc:0.99211
# [45]	eval-auc:0.87955	train-auc:0.99243
# [46]	eval-auc:0.87962	train-auc:0.99274
# [47]	eval-auc:0.87861	train-auc:0.99330
# [48]	eval-auc:0.87895	train-auc:0.99353
# [49]	eval-auc:0.87883	train-auc:0.99395
# [50]	eval-auc:0.87871	train-auc:0.99434
# [51]	eval-auc:0.87845	train-auc:0.99462
# [52]	eval-auc:0.87782	train-auc:0.99475
# [53]	eval-auc:0.87846	train-auc:0.99493
# [54]	eval-auc:0.87848	train-auc:0.99508
# [55]	eval-auc:0.87839	train-auc:0.99523
# [56]	eval-auc:0.87771	train-auc:0.99556
# [57]	eval-auc:0.87786	train-auc:0.99582
# [58]	eval-auc:0.87783	train-auc:0.99603
# [59]	eval-auc:0.87718	train-auc:0.99615
# [60]	eval-auc:0.87678	train-auc:0.99636
# [61]	eval-auc:0.87638	train-auc:0.99649
# [62]	eval-auc:0.87655	train-auc:0.99659
# [63]	eval-auc:0.87585	train-auc:0.99675
# [64]	eval-auc:0.87547	train-auc:0.99691
# [65]	eval-auc:0.87566	train-auc:0.99691
# [66]	eval-auc:0.87588	train-auc:0.99704
# [67]	eval-auc:0.87610	train-auc:0.99712
# [68]	eval-auc:0.87593	train-auc:0.99725
# [69]	eval-auc:0.87572	train-auc:0.99753
# [70]	eval-auc:0.87547	train-auc:0.99775
# [71]	eval-auc:0.87519	train-auc:0.99783
# [72]	eval-auc:0.87484	train-auc:0.99793
# [73]	eval-auc:0.87517	train-auc:0.99796
# [74]	eval-auc:0.87495	train-auc:0.99800
# [75]	eval-auc:0.87527	train-auc:0.99809
# [76]	eval-auc:0.87491	train-auc:0.99813
# [77]	eval-auc:0.87450	train-auc:0.99822
# [78]	eval-auc:0.87441	train-auc:0.99830
# [79]	eval-auc:0.87433	train-auc:0.99840
# [80]	eval-auc:0.87402	train-auc:0.99848
# [81]	eval-auc:0.87415	train-auc:0.99853
# [82]	eval-auc:0.87400	train-auc:0.99858
# [83]	eval-auc:0.87416	train-auc:0.99866
# [84]	eval-auc:0.87422	train-auc:0.99868
# [85]	eval-auc:0.87375	train-auc:0.99879
# [86]	eval-auc:0.87405	train-auc:0.99882
# [87]	eval-auc:0.87416	train-auc:0.99884
# [88]	eval-auc:0.87420	train-auc:0.99892
# [89]	eval-auc:0.87434	train-auc:0.99892
# [90]	eval-auc:0.87448	train-auc:0.99896
# [91]	eval-auc:0.87438	train-auc:0.99903
# [92]	eval-auc:0.87449	train-auc:0.99903
# [93]	eval-auc:0.87461	train-auc:0.99909
# [94]	eval-auc:0.87459	train-auc:0.99916
# [95]	eval-auc:0.87456	train-auc:0.99919
# [96]	eval-auc:0.87456	train-auc:0.99923
# [97]	eval-auc:0.87462	train-auc:0.99925
# [98]	eval-auc:0.87461	train-auc:0.99925
# [99]	eval-auc:0.87471	train-auc:0.99926
# [100]	eval-auc:0.87475	train-auc:0.99928
# [101]	eval-auc:0.87451	train-auc:0.99930
# [102]	eval-auc:0.87441	train-auc:0.99933
# [103]	eval-auc:0.87440	train-auc:0.99938
# [104]	eval-auc:0.87449	train-auc:0.99940
# [105]	eval-auc:0.87447	train-auc:0.99942
# [106]	eval-auc:0.87447	train-auc:0.99943
# [107]	eval-auc:0.87441	train-auc:0.99943
# [108]	eval-auc:0.87432	train-auc:0.99945
# [109]	eval-auc:0.87440	train-auc:0.99945
# [110]	eval-auc:0.87441	train-auc:0.99946
# [111]	eval-auc:0.87456	train-auc:0.99947
# [112]	eval-auc:0.87444	train-auc:0.99952
# [113]	eval-auc:0.87424	train-auc:0.99951
# [114]	eval-auc:0.87441	train-auc:0.99949
# [115]	eval-auc:0.87393	train-auc:0.99952
# [116]	eval-auc:0.87417	train-auc:0.99953
# [117]	eval-auc:0.87373	train-auc:0.99956
# [118]	eval-auc:0.87409	train-auc:0.99957
# [119]	eval-auc:0.87414	train-auc:0.99958
# [120]	eval-auc:0.87382	train-auc:0.99960
# [121]	eval-auc:0.87374	train-auc:0.99964
# [122]	eval-auc:0.87372	train-auc:0.99962
# [123]	eval-auc:0.87402	train-auc:0.99963
# [124]	eval-auc:0.87388	train-auc:0.99965
# [125]	eval-auc:0.87411	train-auc:0.99964
# [126]	eval-auc:0.87413	train-auc:0.99967
# [127]	eval-auc:0.87431	train-auc:0.99968
# [128]	eval-auc:0.87443	train-auc:0.99970
# [129]	eval-auc:0.87447	train-auc:0.99970
# [130]	eval-auc:0.87427	train-auc:0.99971
# [131]	eval-auc:0.87419	train-auc:0.99971
# [132]	eval-auc:0.87456	train-auc:0.99971
# [133]	eval-auc:0.87469	train-auc:0.99972
# [134]	eval-auc:0.87465	train-auc:0.99974
# [135]	eval-auc:0.87434	train-auc:0.99974
# [136]	eval-auc:0.87469	train-auc:0.99975
# [137]	eval-auc:0.87469	train-auc:0.99975
# [138]	eval-auc:0.87471	train-auc:0.99976
# [139]	eval-auc:0.87480	train-auc:0.99976
# [140]	eval-auc:0.87483	train-auc:0.99976
# [141]	eval-auc:0.87491	train-auc:0.99975
# [142]	eval-auc:0.87485	train-auc:0.99975
# [143]	eval-auc:0.87477	train-auc:0.99975
# [144]	eval-auc:0.87506	train-auc:0.99974
# [145]	eval-auc:0.87481	train-auc:0.99975
# [146]	eval-auc:0.87481	train-auc:0.99975
# [147]	eval-auc:0.87481	train-auc:0.99975
# [148]	eval-auc:0.87481	train-auc:0.99975
# [149]	eval-auc:0.87481	train-auc:0.99975
# [150]	eval-auc:0.87489	train-auc:0.99976
# [151]	eval-auc:0.87492	train-auc:0.99976
# [152]	eval-auc:0.87492	train-auc:0.99976
# [153]	eval-auc:0.87513	train-auc:0.99977
# [154]	eval-auc:0.87524	train-auc:0.99977
# [155]	eval-auc:0.87486	train-auc:0.99978
# [156]	eval-auc:0.87466	train-auc:0.99978
# [157]	eval-auc:0.87452	train-auc:0.99979
# [158]	eval-auc:0.87437	train-auc:0.99978
# [159]	eval-auc:0.87454	train-auc:0.99978
# [160]	eval-auc:0.87460	train-auc:0.99980
# [161]	eval-auc:0.87440	train-auc:0.99981
# [162]	eval-auc:0.87440	train-auc:0.99981
# [163]	eval-auc:0.87431	train-auc:0.99980
# [164]	eval-auc:0.87431	train-auc:0.99980
# [165]	eval-auc:0.87413	train-auc:0.99981
# [166]	eval-auc:0.87403	train-auc:0.99981
# [167]	eval-auc:0.87409	train-auc:0.99981
# [168]	eval-auc:0.87410	train-auc:0.99982
# [169]	eval-auc:0.87407	train-auc:0.99982
# [170]	eval-auc:0.87410	train-auc:0.99982
# [171]	eval-auc:0.87410	train-auc:0.99982
# [172]	eval-auc:0.87431	train-auc:0.99983
# [173]	eval-auc:0.87460	train-auc:0.99983
# [174]	eval-auc:0.87449	train-auc:0.99984
# [175]	eval-auc:0.87457	train-auc:0.99984
# [176]	eval-auc:0.87439	train-auc:0.99985
# [177]	eval-auc:0.87439	train-auc:0.99985
# [178]	eval-auc:0.87447	train-auc:0.99985
# [179]	eval-auc:0.87447	train-auc:0.99985
# [180]	eval-auc:0.87465	train-auc:0.99985
# [181]	eval-auc:0.87470	train-auc:0.99985
# [182]	eval-auc:0.87467	train-auc:0.99986
# [183]	eval-auc:0.87475	train-auc:0.99987
# [184]	eval-auc:0.87469	train-auc:0.99987
# [185]	eval-auc:0.87469	train-auc:0.99987
# [186]	eval-auc:0.87458	train-auc:0.99988
# [187]	eval-auc:0.87465	train-auc:0.99989
# [188]	eval-auc:0.87478	train-auc:0.99988
# [189]	eval-auc:0.87483	train-auc:0.99988
# [190]	eval-auc:0.87470	train-auc:0.99988
# [191]	eval-auc:0.87477	train-auc:0.99989
# [192]	eval-auc:0.87505	train-auc:0.99989
# [193]	eval-auc:0.87518	train-auc:0.99989
# [194]	eval-auc:0.87490	train-auc:0.99989
# [195]	eval-auc:0.87483	train-auc:0.99989
# [196]	eval-auc:0.87507	train-auc:0.99990
# [197]	eval-auc:0.87507	train-auc:0.99990
# [198]	eval-auc:0.87514	train-auc:0.99991
# [199]	eval-auc:0.87513	train-auc:0.99991
# [200]	eval-auc:0.87501	train-auc:0.99991
# [201]	eval-auc:0.87501	train-auc:0.99991
# [202]	eval-auc:0.87501	train-auc:0.99991
# [203]	eval-auc:0.87494	train-auc:0.99991
# [204]	eval-auc:0.87502	train-auc:0.99991
# [205]	eval-auc:0.87502	train-auc:0.99991
# [206]	eval-auc:0.87519	train-auc:0.99992
# [207]	eval-auc:0.87519	train-auc:0.99992
# [208]	eval-auc:0.87519	train-auc:0.99992
# [209]	eval-auc:0.87513	train-auc:0.99992
# [210]	eval-auc:0.87513	train-auc:0.99992
# [211]	eval-auc:0.87499	train-auc:0.99992
# [212]	eval-auc:0.87487	train-auc:0.99993
# [213]	eval-auc:0.87487	train-auc:0.99993
# [214]	eval-auc:0.87487	train-auc:0.99993
# [215]	eval-auc:0.87505	train-auc:0.99993
# [216]	eval-auc:0.87481	train-auc:0.99993
# [217]	eval-auc:0.87493	train-auc:0.99993
# [218]	eval-auc:0.87493	train-auc:0.99993
# [219]	eval-auc:0.87484	train-auc:0.99993
# [220]	eval-auc:0.87466	train-auc:0.99993
# [221]	eval-auc:0.87480	train-auc:0.99993
# [222]	eval-auc:0.87475	train-auc:0.99993
# [223]	eval-auc:0.87510	train-auc:0.99994
# [224]	eval-auc:0.87510	train-auc:0.99994
# [225]	eval-auc:0.87491	train-auc:0.99994
# [226]	eval-auc:0.87506	train-auc:0.99994
# [227]	eval-auc:0.87525	train-auc:0.99995
# [228]	eval-auc:0.87525	train-auc:0.99995
# [229]	eval-auc:0.87512	train-auc:0.99995
# [230]	eval-auc:0.87512	train-auc:0.99995
# [231]	eval-auc:0.87505	train-auc:0.99994
# [232]	eval-auc:0.87491	train-auc:0.99994
# [233]	eval-auc:0.87471	train-auc:0.99994
# [234]	eval-auc:0.87471	train-auc:0.99994
# [235]	eval-auc:0.87471	train-auc:0.99994
# [236]	eval-auc:0.87469	train-auc:0.99994
# [237]	eval-auc:0.87459	train-auc:0.99994
# [238]	eval-auc:0.87472	train-auc:0.99994
# [239]	eval-auc:0.87472	train-auc:0.99994
# [240]	eval-auc:0.87465	train-auc:0.99994
# [241]	eval-auc:0.87444	train-auc:0.99994
# [242]	eval-auc:0.87444	train-auc:0.99994
# [243]	eval-auc:0.87444	train-auc:0.99994
# [244]	eval-auc:0.87434	train-auc:0.99994
# [245]	eval-auc:0.87434	train-auc:0.99994
# [246]	eval-auc:0.87434	train-auc:0.99994
# [247]	eval-auc:0.87434	train-auc:0.99994
# [248]	eval-auc:0.87434	train-auc:0.99994
# [249]	eval-auc:0.87434	train-auc:0.99994
# [250]	eval-auc:0.87444	train-auc:0.99994
# [251]	eval-auc:0.87474	train-auc:0.99994
# [252]	eval-auc:0.87480	train-auc:0.99994
# [253]	eval-auc:0.87456	train-auc:0.99993
# [254]	eval-auc:0.87455	train-auc:0.99993
# [255]	eval-auc:0.87460	train-auc:0.99993
# [256]	eval-auc:0.87460	train-auc:0.99993
# [257]	eval-auc:0.87468	train-auc:0.99993
# [258]	eval-auc:0.87491	train-auc:0.99993
# [259]	eval-auc:0.87494	train-auc:0.99994
# [260]	eval-auc:0.87471	train-auc:0.99994
# [261]	eval-auc:0.87471	train-auc:0.99994
# [262]	eval-auc:0.87465	train-auc:0.99994
# [263]	eval-auc:0.87446	train-auc:0.99994
# [264]	eval-auc:0.87443	train-auc:0.99994
# [265]	eval-auc:0.87419	train-auc:0.99994
# [266]	eval-auc:0.87419	train-auc:0.99994
# [267]	eval-auc:0.87419	train-auc:0.99994
# [268]	eval-auc:0.87431	train-auc:0.99995
# [269]	eval-auc:0.87433	train-auc:0.99995
# [270]	eval-auc:0.87424	train-auc:0.99995
# [271]	eval-auc:0.87444	train-auc:0.99995
# [272]	eval-auc:0.87418	train-auc:0.99995
# [273]	eval-auc:0.87418	train-auc:0.99995
# [274]	eval-auc:0.87418	train-auc:0.99995
# [275]	eval-auc:0.87443	train-auc:0.99995
# [276]	eval-auc:0.87443	train-auc:0.99995
# [277]	eval-auc:0.87438	train-auc:0.99996
# [278]	eval-auc:0.87438	train-auc:0.99996
# [279]	eval-auc:0.87438	train-auc:0.99996
# [280]	eval-auc:0.87438	train-auc:0.99996
# [281]	eval-auc:0.87421	train-auc:0.99996
# [282]	eval-auc:0.87421	train-auc:0.99996
# [283]	eval-auc:0.87412	train-auc:0.99996
# [284]	eval-auc:0.87414	train-auc:0.99997
# [285]	eval-auc:0.87418	train-auc:0.99997
# [286]	eval-auc:0.87418	train-auc:0.99997
# [287]	eval-auc:0.87418	train-auc:0.99997
# [288]	eval-auc:0.87418	train-auc:0.99997
# [289]	eval-auc:0.87411	train-auc:0.99997
# [290]	eval-auc:0.87404	train-auc:0.99997
# [291]	eval-auc:0.87404	train-auc:0.99997
# [292]	eval-auc:0.87412	train-auc:0.99997
# [293]	eval-auc:0.87412	train-auc:0.99997
# [294]	eval-auc:0.87412	train-auc:0.99997
# [295]	eval-auc:0.87408	train-auc:0.99997
# [296]	eval-auc:0.87408	train-auc:0.99997
# [297]	eval-auc:0.87408	train-auc:0.99997
# [298]	eval-auc:0.87408	train-auc:0.99997
# [299]	eval-auc:0.87408	train-auc:0.99997
# [300]	eval-auc:0.87416	train-auc:0.99997
# [301]	eval-auc:0.87416	train-auc:0.99997
# [302]	eval-auc:0.87405	train-auc:0.99997
# [303]	eval-auc:0.87393	train-auc:0.99997
# [304]	eval-auc:0.87391	train-auc:0.99997
# [305]	eval-auc:0.87391	train-auc:0.99997
# [306]	eval-auc:0.87391	train-auc:0.99997
# [307]	eval-auc:0.87389	train-auc:0.99997
# [308]	eval-auc:0.87389	train-auc:0.99997
# [309]	eval-auc:0.87389	train-auc:0.99997
# [310]	eval-auc:0.87389	train-auc:0.99997
# [311]	eval-auc:0.87400	train-auc:0.99998
# [312]	eval-auc:0.87400	train-auc:0.99998
# [313]	eval-auc:0.87408	train-auc:0.99998
# ...
# [289]	eval-auc:0.88165	train-auc:0.98213
# [290]	eval-auc:0.88115	train-auc:0.98225
# [291]	eval-auc:0.88117	train-auc:0.98238
# [292]	eval-auc:0.88083	train-auc:0.98247
# [293]	eval-auc:0.88062	train-auc:0.98263
# [294]	eval-auc:0.88074	train-auc:0.98267
# [295]	eval-auc:0.88077	train-auc:0.98265
# [296]	eval-auc:0.88060	train-auc:0.98275
# [297]	eval-auc:0.88046	train-auc:0.98301
# [298]	eval-auc:0.88045	train-auc:0.98298
# [299]	eval-auc:0.88043	train-auc:0.98301
# [300]	eval-auc:0.88038	train-auc:0.98304
# [301]	eval-auc:0.88025	train-auc:0.98312
# [302]	eval-auc:0.88045	train-auc:0.98316
# [303]	eval-auc:0.88063	train-auc:0.98324
# [304]	eval-auc:0.88055	train-auc:0.98337
# [305]	eval-auc:0.88056	train-auc:0.98336
# [306]	eval-auc:0.88070	train-auc:0.98333
# [307]	eval-auc:0.88077	train-auc:0.98338
# [308]	eval-auc:0.88059	train-auc:0.98351
# [309]	eval-auc:0.88048	train-auc:0.98358
# [310]	eval-auc:0.88027	train-auc:0.98383
# [311]	eval-auc:0.88035	train-auc:0.98388
# [312]	eval-auc:0.88044	train-auc:0.98398
# [313]	eval-auc:0.88032	train-auc:0.98407
# [314]	eval-auc:0.88038	train-auc:0.98412
# [315]	eval-auc:0.88018	train-auc:0.98418
# [316]	eval-auc:0.88032	train-auc:0.98428
# [317]	eval-auc:0.88022	train-auc:0.98433
# [318]	eval-auc:0.88021	train-auc:0.98445
# [319]	eval-auc:0.88022	train-auc:0.98452
# [320]	eval-auc:0.88018	train-auc:0.98463
# [321]	eval-auc:0.88004	train-auc:0.98466
# [322]	eval-auc:0.87993	train-auc:0.98472
# [323]	eval-auc:0.87956	train-auc:0.98485
# [324]	eval-auc:0.87965	train-auc:0.98500
# [325]	eval-auc:0.87976	train-auc:0.98505
# [326]	eval-auc:0.87985	train-auc:0.98516
# [327]	eval-auc:0.87989	train-auc:0.98513
# [328]	eval-auc:0.87999	train-auc:0.98511
# [329]	eval-auc:0.88003	train-auc:0.98521
# [330]	eval-auc:0.88013	train-auc:0.98525
# [331]	eval-auc:0.88001	train-auc:0.98531
# [332]	eval-auc:0.87994	train-auc:0.98531
# [333]	eval-auc:0.87996	train-auc:0.98538
# [334]	eval-auc:0.88004	train-auc:0.98543
# [335]	eval-auc:0.88013	train-auc:0.98547
# [336]	eval-auc:0.87993	train-auc:0.98562
# [337]	eval-auc:0.88016	train-auc:0.98564
# [338]	eval-auc:0.88020	train-auc:0.98574
# [339]	eval-auc:0.88004	train-auc:0.98583
# [340]	eval-auc:0.88002	train-auc:0.98599
# [341]	eval-auc:0.88009	train-auc:0.98603
# [342]	eval-auc:0.88008	train-auc:0.98613
# [343]	eval-auc:0.88005	train-auc:0.98623
# [344]	eval-auc:0.88012	train-auc:0.98625
# [345]	eval-auc:0.88006	train-auc:0.98627
# [346]	eval-auc:0.88003	train-auc:0.98632
# [347]	eval-auc:0.88017	train-auc:0.98636
# [348]	eval-auc:0.88021	train-auc:0.98639
# [349]	eval-auc:0.88023	train-auc:0.98638
# [350]	eval-auc:0.88030	train-auc:0.98650
# [351]	eval-auc:0.88030	train-auc:0.98650
# [352]	eval-auc:0.88010	train-auc:0.98661
# [353]	eval-auc:0.87999	train-auc:0.98674
# [354]	eval-auc:0.87974	train-auc:0.98680
# [355]	eval-auc:0.87975	train-auc:0.98688
# [356]	eval-auc:0.87975	train-auc:0.98690
# [357]	eval-auc:0.87992	train-auc:0.98698
# [358]	eval-auc:0.87995	train-auc:0.98705
# [359]	eval-auc:0.88004	train-auc:0.98705
# [360]	eval-auc:0.88012	train-auc:0.98706
# [361]	eval-auc:0.88014	train-auc:0.98713
# [362]	eval-auc:0.88024	train-auc:0.98716
# [363]	eval-auc:0.88018	train-auc:0.98725
# [364]	eval-auc:0.88023	train-auc:0.98729
# [365]	eval-auc:0.88025	train-auc:0.98730
# [366]	eval-auc:0.88022	train-auc:0.98729
# [367]	eval-auc:0.87997	train-auc:0.98742
# [368]	eval-auc:0.88005	train-auc:0.98745
# [369]	eval-auc:0.87999	train-auc:0.98753
# [370]	eval-auc:0.88008	train-auc:0.98758
# [371]	eval-auc:0.88006	train-auc:0.98759
# [372]	eval-auc:0.88006	train-auc:0.98759
# [373]	eval-auc:0.87992	train-auc:0.98766
# [374]	eval-auc:0.87995	train-auc:0.98780
# [375]	eval-auc:0.87994	train-auc:0.98780
# [376]	eval-auc:0.88007	train-auc:0.98781
# [377]	eval-auc:0.87987	train-auc:0.98798
# [378]	eval-auc:0.87985	train-auc:0.98799
# [379]	eval-auc:0.87997	train-auc:0.98801
# [380]	eval-auc:0.87993	train-auc:0.98802
# [381]	eval-auc:0.87998	train-auc:0.98805
# [382]	eval-auc:0.87997	train-auc:0.98814
# [383]	eval-auc:0.87983	train-auc:0.98825
# [384]	eval-auc:0.87972	train-auc:0.98823
# [385]	eval-auc:0.87972	train-auc:0.98825
# [386]	eval-auc:0.87974	train-auc:0.98833
# [387]	eval-auc:0.87964	train-auc:0.98833
# [388]	eval-auc:0.87948	train-auc:0.98839
# [389]	eval-auc:0.87966	train-auc:0.98843
# [390]	eval-auc:0.87978	train-auc:0.98847
# [391]	eval-auc:0.87977	train-auc:0.98849
# [392]	eval-auc:0.88001	train-auc:0.98851
# [393]	eval-auc:0.87989	train-auc:0.98859
# [394]	eval-auc:0.87989	train-auc:0.98859
# [395]	eval-auc:0.87971	train-auc:0.98863
# [396]	eval-auc:0.87955	train-auc:0.98868
# [397]	eval-auc:0.87941	train-auc:0.98870
# [398]	eval-auc:0.87939	train-auc:0.98872
# [399]	eval-auc:0.87916	train-auc:0.98879
# [400]	eval-auc:0.87922	train-auc:0.98877
# [401]	eval-auc:0.87926	train-auc:0.98879
# [402]	eval-auc:0.87931	train-auc:0.98880
# [403]	eval-auc:0.87894	train-auc:0.98892
# [404]	eval-auc:0.87884	train-auc:0.98897
# [405]	eval-auc:0.87892	train-auc:0.98904
# [406]	eval-auc:0.87884	train-auc:0.98914
# [407]	eval-auc:0.87865	train-auc:0.98923
# [408]	eval-auc:0.87875	train-auc:0.98923
# [409]	eval-auc:0.87886	train-auc:0.98923
# [410]	eval-auc:0.87891	train-auc:0.98927
# [411]	eval-auc:0.87892	train-auc:0.98924
# [412]	eval-auc:0.87878	train-auc:0.98928
# [413]	eval-auc:0.87860	train-auc:0.98928
# [414]	eval-auc:0.87842	train-auc:0.98930
# [415]	eval-auc:0.87830	train-auc:0.98931
# [416]	eval-auc:0.87842	train-auc:0.98929
# [417]	eval-auc:0.87847	train-auc:0.98942
# [418]	eval-auc:0.87847	train-auc:0.98945
# [419]	eval-auc:0.87847	train-auc:0.98962
# [420]	eval-auc:0.87843	train-auc:0.98963
# [421]	eval-auc:0.87837	train-auc:0.98971
# [422]	eval-auc:0.87828	train-auc:0.98972
# [423]	eval-auc:0.87842	train-auc:0.98976
# [424]	eval-auc:0.87836	train-auc:0.98981
# [425]	eval-auc:0.87834	train-auc:0.98980
# [426]	eval-auc:0.87834	train-auc:0.98980
# [427]	eval-auc:0.87848	train-auc:0.98984
# [428]	eval-auc:0.87839	train-auc:0.98984
# [429]	eval-auc:0.87823	train-auc:0.98996
# [430]	eval-auc:0.87806	train-auc:0.98998
# [431]	eval-auc:0.87812	train-auc:0.99001
# [432]	eval-auc:0.87814	train-auc:0.99005
# [433]	eval-auc:0.87802	train-auc:0.99005
# [434]	eval-auc:0.87797	train-auc:0.99010
# [435]	eval-auc:0.87797	train-auc:0.99013
# [436]	eval-auc:0.87788	train-auc:0.99013
# [437]	eval-auc:0.87781	train-auc:0.99016
# [438]	eval-auc:0.87784	train-auc:0.99017
# [439]	eval-auc:0.87784	train-auc:0.99016
# [440]	eval-auc:0.87799	train-auc:0.99019
# [441]	eval-auc:0.87814	train-auc:0.99018
# [442]	eval-auc:0.87819	train-auc:0.99018
# [443]	eval-auc:0.87812	train-auc:0.99028
# [444]	eval-auc:0.87794	train-auc:0.99029
# [445]	eval-auc:0.87794	train-auc:0.99029
# [446]	eval-auc:0.87807	train-auc:0.99032
# [447]	eval-auc:0.87799	train-auc:0.99039
# [448]	eval-auc:0.87796	train-auc:0.99046
# [449]	eval-auc:0.87795	train-auc:0.99046
# [450]	eval-auc:0.87796	train-auc:0.99046
# [451]	eval-auc:0.87785	train-auc:0.99051
# [452]	eval-auc:0.87792	train-auc:0.99057
# [453]	eval-auc:0.87792	train-auc:0.99057
# [454]	eval-auc:0.87794	train-auc:0.99057
# [455]	eval-auc:0.87783	train-auc:0.99063
# [456]	eval-auc:0.87780	train-auc:0.99066
# [457]	eval-auc:0.87797	train-auc:0.99064
# [458]	eval-auc:0.87773	train-auc:0.99076
# [459]	eval-auc:0.87771	train-auc:0.99077
# [460]	eval-auc:0.87760	train-auc:0.99077
# [461]	eval-auc:0.87780	train-auc:0.99077
# [462]	eval-auc:0.87769	train-auc:0.99085
# [463]	eval-auc:0.87760	train-auc:0.99092
# [464]	eval-auc:0.87749	train-auc:0.99099
# [465]	eval-auc:0.87743	train-auc:0.99105
# [466]	eval-auc:0.87736	train-auc:0.99109
# [467]	eval-auc:0.87732	train-auc:0.99108
# [468]	eval-auc:0.87726	train-auc:0.99110
# [469]	eval-auc:0.87717	train-auc:0.99120
# [470]	eval-auc:0.87728	train-auc:0.99121
# [471]	eval-auc:0.87711	train-auc:0.99128
# [472]	eval-auc:0.87706	train-auc:0.99130
# [473]	eval-auc:0.87718	train-auc:0.99132
# [474]	eval-auc:0.87718	train-auc:0.99138
# [475]	eval-auc:0.87719	train-auc:0.99139
# [476]	eval-auc:0.87732	train-auc:0.99137
# [477]	eval-auc:0.87713	train-auc:0.99146
# [478]	eval-auc:0.87708	train-auc:0.99150
# [479]	eval-auc:0.87708	train-auc:0.99152
# 	Score 0.8770840806865532
#
#
# 100%|████████| 50/50 [03:23<00:00,  4.07s/trial, best loss: 0.10883624456156815]
# The best hyperparameters are:
#
# {'colsample_bytree': 0.5, 'eta': 0.025, 'gamma': 0.75, 'max_depth': 3, 'min_child_weight': 6.0, 'n_estimators': 465.0, 'subsample': 0.8500000000000001}
# /Users/haseung-won/opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:91: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HomePlanet    8693 non-null   int64
#  1   CryoSleep     8693 non-null   int64
#  2   Destination   8693 non-null   int64
#  3   Age           8693 non-null   int64
#  4   VIP           8693 non-null   int64
#  5   RoomService   8693 non-null   int64
#  6   FoodCourt     8693 non-null   int64
#  7   ShoppingMall  8693 non-null   int64
#  8   Spa           8693 non-null   int64
#  9   VRDeck        8693 non-null   int64
#  10  group         8693 non-null   int64
#  11  group_num     8693 non-null   int64
#  12  Cabin_deck    8693 non-null   int64
#  13  Cabin_num     8693 non-null   int64
#  14  Cabin_side    8693 non-null   int64
#  15  Age_band      8693 non-null   int64
# dtypes: int64(16)
# memory usage: 1.1 MB
